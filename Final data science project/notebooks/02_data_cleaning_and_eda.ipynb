# %% [markdown]
# # Hospital Length of Stay Dataset
# ## Data Cleaning and Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/raw/LengthOfStay.csv")
df.head()
# Out:
#    eid       vdate rcount gender  dialysisrenalendstage  asthma  irondef  \
# 0    1   8/29/2012      0      F                      0       0        0
# 1    2   5/26/2012     5+      F                      0       0        0
# 2    3   9/22/2012      1      F                      0       0        0
# 3    4    8/9/2012      0      F                      0       0        0
# 4    5  12/20/2012      0      F                      0       0        0
#
#    pneum  substancedependence  psychologicaldisordermajor  ...     glucose  \
# 0      0                    0                           0  ...  192.476918
# 1      0                    0                           0  ...   94.078507
# 2      0                    0                           0  ...  130.530524
# 3      0                    0                           0  ...  163.377028
# 4      1                    0                           1  ...   94.886654
#
#    bloodureanitro  creatinine        bmi  pulse  respiration  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Duplicate Records
#
# The dataset was checked for duplicates and **no duplicate rows were found**, so no records were removed.

# %%
df.isnull().sum()
# Out:
# eid                           0
# vdate                         0
# rcount                        0
# gender                        0
# dialysisrenalendstage         0
# asthma                        0
# irondef                       0
# pneum                         0
# substancedependence           0
# psychologicaldisordermajor    0
# depress                       0
# psychother                    0
# fibrosisandother              0
# malnutrition                  0
# hemo                          0
# hematocrit                    0
# neutrophils                   0
# sodium                        0
# glucose                       0
# bloodureanitro                0
# creatinine                    0
# bmi                           0
# pulse                         0
# respiration                   0
# secondarydiagnosisnonicd9     0
# discharged                    0
# facid                         0
# lengthofstay                  0
# dtype: int64

# %% [markdown]
# ## Missing Values Handling
#
# After checking missing values using `df.isnull().sum()`, the dataset showed **no missing values** across all columns.
# Therefore, no imputation was required for this dataset.

# %%
for col in df.columns:
    if df[col].dtype == "object":
        print(col)
        print(df[col].unique())
        print("-" * 40)
# Out:
# vdate
# ['8/29/2012' '5/26/2012' '9/22/2012' '8/9/2012' '12/20/2012' '11/27/2012'
#  '9/27/2012' '6/4/2012' '7/5/2012' '9/1/2012' '5/11/2012' '4/21/2012'
#  '7/8/2012' '12/5/2012' '6/15/2012' '3/14/2012' '12/10/2012' '10/24/2012'
#  '7/10/2012' '6/6/2012' '7/31/2012' '8/24/2012' '12/26/2012' '3/10/2012'
#  '6/14/2012' '6/28/2012' '5/13/2012' '1/12/2012' '11/11/2012' '7/24/2012'
#  '8/4/2012' '7/15/2012' '4/13/2012' '10/26/2012' '11/23/2012' '4/8/2012'
#  '12/4/2012' '10/5/2012' '5/5/2012' '11/1/2012' '4/30/2012' '2/22/2012'
#  '1/9/2012' '8/25/2012' '9/9/2012' '7/29/2012' '3/1/2012' '10/25/2012'
#  '11/2/2012' '9/2/2012' '11/3/2012' '5/25/2012' '4/11/2012' '3/13/2012'
#  '1/23/2012' '6/24/2012' '3/30/2012' '10/7/2012' '9/25/2012' '11/25/2012'
#  '5/24/2012' '7/22/2012' '7/14/2012' '2/1/2012' '10/30/2012' '10/28/2012'
#  '4/12/2012' '1/21/2012' '12/28/2012' '6/29/2012' '11/20/2012' '2/20/2012'
#  '8/23/2012' '12/12/2012' '10/29/2012' '10/22/2012' '9/3/2012' '2/7/2012'
# ...

# %%
df.hist(figsize=(14, 10))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exploratory Data Analysis EDA  Observations
#
# - Numerical variables show varying distributions, indicating differences in patient conditions.
# - Some variables are skewed, suggesting the presence of outliers.
# - These insights will help in selecting and preparing features for modeling.
